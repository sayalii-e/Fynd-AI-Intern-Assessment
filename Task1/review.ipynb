# %%
# pip install python-dotenv groq pandas tqdm
# Out:
# Requirement already satisfied: python-dotenv in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (1.2.1)
# Requirement already satisfied: groq in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (0.37.1)
# Requirement already satisfied: pandas in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: tqdm in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (4.67.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (from groq) (0.28.1)
# Requirement already satisfied: sniffio in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (from groq) (1.3.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (from groq) (1.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (from groq) (4.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (from groq) (2.12.5)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (from groq) (4.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: tzdata>=2022.7 in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: colorama in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: idna>=2.8 in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (from anyio<5,>=3.5.0->groq) (3.11)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (from anyio<5,>=3.5.0->groq) (1.3.1)
# Requirement already satisfied: httpcore==1.* in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: certifi in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (from httpx<1,>=0.23.0->groq) (2025.11.12)
# Requirement already satisfied: h11>=0.16 in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (from pydantic<3,>=1.9.0->groq) (2.41.5)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: six>=1.5 in c:\all data\projects\fynd-ai-intern-assessment\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# --- Cell 1: Imports and setup ---
import os
import json
import pandas as pd
from tqdm import tqdm
from dotenv import load_dotenv
from groq import Groq
import re

# Load environment variables from .env file
load_dotenv()

# Initialize Groq client
api_key = os.getenv("GROQ_API_KEY")

client = Groq(api_key=api_key)

# %%
df = pd.read_csv("yelp.csv").sample(200, random_state=42)
df.head()
# Out:
#                  business_id        date               review_id  stars  \
# 6252  QVR7dsvBeg8xFt9B-vd1BA  2010-07-22  hwYVJs8Ko4PMjI19QcR57g      4
# 4684  24qSrF_XOrvaHDBy-gLIQg  2012-01-22  0mvthYPKb2ZmKhCADiKSmQ      5
# 1731  j0Uc-GuOe-x9_N_IK1KPpA  2009-05-09  XJHknNIecha6h0wkBSZB4w      3
# 4742  RBiiGw8c7j-0a8nk35JO3w  2010-12-22  z6y3GRpYDqTznVe-0dn--Q      1
# 4521  U8VA-RW6LYOhxR-Ygi6eDw  2011-01-17  vhWHdemMvsqVNv5zi2OMiA      5
#
#                                                    text    type  \
# 6252  We got here around midnight last Friday... the...  review
# 4684  Brought a friend from Louisiana here.  She say...  review
# 1731  Every friday, my dad and I eat here. We order ...  review
# 4742  My husband and I were really, really disappoin...  review
# 4521  Love this place!  Was in phoenix 3 weeks for w...  review
#
#                      user_id  cool  useful  funny
# 6252  90a6z--_CUrl84aCzZyPsg     5       5      2
# 4684  9lJAj_2zCvP2jcEiRjF9oA     0       0      0
# 1731  0VfJi9Au0rVFVnPKcJpt3Q     0       0      0
# 4742  lwppVF0Yqkuwt-xaEuugqw     2       2      2
# 4521  Y2R_tlSk4lTHiLXTDsn1rg     0       1      0

# %% [markdown]
# ### Prompt 1

# %%
prompts = ["Classify this Yelp review into 1-5 stars. Provide only a JSON output with 'review_text' and 'star_rating' : '{}'"]

detailed_results = []

for p in prompts:
    correct = 0
    total = 0
    valid_json = 0
    
    print(f"\n Running prompt: {p[:50]}...\n")
    for _, row in tqdm(df.iterrows(), total=len(df)):
        review = row["text"]
        actual = row["stars"]
        
        messages = [
            {"role": "system", "content": "You are an expert at sentiment analysis"},
            {"role": "user", "content": p.format(review)},
        ]
        
        response = client.chat.completions.create(
            model="llama-3.3-70b-versatile",  
            messages=messages,
            temperature=0.3,
            max_tokens=100,
        )
        
        raw_output = response.choices[0].message.content.strip()

        pred = None
        try:
            pred = json.loads(raw_output)
            predicted = pred.get("star_rating", None)
            valid_json += 1
        except json.JSONDecodeError:
            match = re.search(r"\b[1-5]\b", raw_output)
            predicted = int(match.group()) if match else None

        if predicted is not None and predicted == actual:
            correct += 1

        total += 1
        
        detailed_results.append({
            "Review": review[:150] + ("..." if len(review) > 150 else ""), 
            "Predicted Rating": predicted,
            "Actual Rating": actual,
            "Match": predicted == actual,
            "Valid JSON": "True" if isinstance(pred, dict) else "False",
            "Raw Model Output": raw_output
        })

accuracy = round(correct / total, 3) if total > 0 else 0
json_validity = round(valid_json / total, 3) if total > 0 else 0
results_df = pd.DataFrame(detailed_results)
print("\n Results:")
print(results_df)
print(f"\n Accuracy: {accuracy}")
print(f"\n JSON Validity: {json_validity}")
# Out:
#  Running prompt: Classify this Yelp review into 1-5 stars. Provide ...
#  ... (more hidden) ...

# %% [markdown]
# ### Prompt 2

# %%
prompts = ["Analyze this text carefully and rate it from 1–5 stars based on the reviewer’s satisfaction (1 = very dissatisfied, 5 = very satisfied). Provide JSON output {{'review_text': '...', 'star_rating': <1–5>}}: '{}'"]

detailed_results = []

for p in prompts:
    correct = 0
    total = 0
    valid_json = 0
    
    print(f"\n Running prompt: {p[:50]}...\n")
    for _, row in tqdm(df.iterrows(), total=len(df)):
        review = row["text"]
        actual = row["stars"]
        
        messages = [
            {"role": "system", "content": "You are an expert at sentiment analysis. Always return a JSON object with 'review_text' and 'star_rating'."},
            {"role": "user", "content": p.format(review)},
        ]
        
        response = client.chat.completions.create(
            model="llama-3.3-70b-versatile",  
            messages=messages,
            temperature=0.3,
            max_tokens=100,
        )
        
        raw_output = response.choices[0].message.content.strip()

        pred = None
        try:
            pred = json.loads(raw_output)
            predicted = pred.get("star_rating", None)
            valid_json += 1
        except json.JSONDecodeError:
            match = re.search(r"\b[1-5]\b", raw_output)
            predicted = int(match.group()) if match else None

        if predicted is not None and predicted == actual:
            correct += 1

        total += 1
        
        detailed_results.append({
            "Review": review[:150] + ("..." if len(review) > 150 else ""), 
            "Predicted Rating": predicted,
            "Actual Rating": actual,
            "Match": predicted == actual,
            "Valid JSON": "True" if isinstance(pred, dict) else "False",
            "Raw Model Output": raw_output
        })

accuracy = round(correct / total, 3) if total > 0 else 0
json_validity = round(valid_json / total, 3) if total > 0 else 0
results_df = pd.DataFrame(detailed_results)
print("\n Results:")
print(results_df)
print(f"\n Accuracy: {accuracy}")
print(f"\n JSON Validity: {json_validity}")

# %% [markdown]
# ### Prompt 3

# %%
prompts = ["Consider both positive and negative aspects of this Yelp review, and decide the most accurate 1–5 star rating that reflects overall satisfaction. Strictly provide only a JSON output with 'review_text' and 'star_rating' : '{}'"]

detailed_results = []

for p in prompts:
    correct = 0
    total = 0
    valid_json = 0
    
    print(f"\n Running prompt: {p[:50]}...\n")
    for _, row in tqdm(df.iterrows(), total=len(df)):
        review = row["text"]
        actual = row["stars"]
        
        messages = [
            {"role": "system", "content": "You are an expert at sentiment analysis. Always return a JSON object with 'review_text' and 'star_rating'."},
            {"role": "user", "content": p.format(review)},
        ]
        
        response = client.chat.completions.create(
            model="llama-3.3-70b-versatile",  
            messages=messages,
            temperature=0.3,
            max_tokens=100,
        )
        
        raw_output = response.choices[0].message.content.strip()

        pred = None
        try:
            pred = json.loads(raw_output)
            predicted = pred.get("star_rating", None)
            valid_json += 1
        except json.JSONDecodeError:
            match = re.search(r"\b[1-5]\b", raw_output)
            predicted = int(match.group()) if match else None

        if predicted is not None and predicted == actual:
            correct += 1

        total += 1
        
        detailed_results.append({
            "Review": review[:150] + ("..." if len(review) > 150 else ""), 
            "Predicted Rating": predicted,
            "Actual Rating": actual,
            "Match": predicted == actual,
            "Valid JSON": "True" if isinstance(pred, dict) else "False",
            "Raw Model Output": raw_output
        })

accuracy = round(correct / total, 3) if total > 0 else 0
json_validity = round(valid_json / total, 3) if total > 0 else 0
results_df = pd.DataFrame(detailed_results)
print("\n Results:")
print(results_df)
print(f"\n Accuracy: {accuracy}")
print(f"\n JSON Validity: {json_validity}")
