# %%
# pip install python-dotenv groq pandas tqdm

# %%
# --- Cell 1: Imports and setup ---
import os
import json
import pandas as pd
from tqdm import tqdm
from dotenv import load_dotenv
from groq import Groq
import re

# Load environment variables from .env file
load_dotenv()

# Initialize Groq client
api_key = os.getenv("GROQ_API_KEY")

client = Groq(api_key=api_key)

# %%
df = pd.read_csv("yelp.csv").sample(50, random_state=42)
df.head()
# Out:
#                  business_id        date               review_id  stars  \
# 6252  QVR7dsvBeg8xFt9B-vd1BA  2010-07-22  hwYVJs8Ko4PMjI19QcR57g      4
# 4684  24qSrF_XOrvaHDBy-gLIQg  2012-01-22  0mvthYPKb2ZmKhCADiKSmQ      5
# 1731  j0Uc-GuOe-x9_N_IK1KPpA  2009-05-09  XJHknNIecha6h0wkBSZB4w      3
# 4742  RBiiGw8c7j-0a8nk35JO3w  2010-12-22  z6y3GRpYDqTznVe-0dn--Q      1
# 4521  U8VA-RW6LYOhxR-Ygi6eDw  2011-01-17  vhWHdemMvsqVNv5zi2OMiA      5
#
#                                                    text    type  \
# 6252  We got here around midnight last Friday... the...  review
# 4684  Brought a friend from Louisiana here.  She say...  review
# 1731  Every friday, my dad and I eat here. We order ...  review
# 4742  My husband and I were really, really disappoin...  review
# 4521  Love this place!  Was in phoenix 3 weeks for w...  review
#
#                      user_id  cool  useful  funny
# 6252  90a6z--_CUrl84aCzZyPsg     5       5      2
# 4684  9lJAj_2zCvP2jcEiRjF9oA     0       0      0
# 1731  0VfJi9Au0rVFVnPKcJpt3Q     0       0      0
# 4742  lwppVF0Yqkuwt-xaEuugqw     2       2      2
# 4521  Y2R_tlSk4lTHiLXTDsn1rg     0       1      0

# %% [markdown]
# ### Prompt 1

# %%
prompts = ["Classify this Yelp review into 1-5 stars. Provide only a JSON output with 'review_text' and 'star_rating' : '{}'"]

detailed_results = []

for p in prompts:
    correct = 0
    total = 0
    valid_json = 0
    
    print(f"\n Running prompt: {p[:50]}...\n")
    for _, row in tqdm(df.iterrows(), total=len(df)):
        review = row["text"]
        actual = row["stars"]
        
        messages = [
            {"role": "system", "content": "You are an expert at sentiment analysis"},
            {"role": "user", "content": p.format(review)},
        ]
        
        response = client.chat.completions.create(
            model="llama-3.3-70b-versatile",  
            messages=messages,
            temperature=0.3,
            max_tokens=100,
        )
        
        raw_output = response.choices[0].message.content.strip()

        pred = None
        try:
            pred = json.loads(raw_output)
            predicted = pred.get("star_rating", None)
            valid_json += 1
        except json.JSONDecodeError:
            match = re.search(r"\b[1-5]\b", raw_output)
            predicted = int(match.group()) if match else None

        if predicted is not None and predicted == actual:
            correct += 1

        total += 1
        
        detailed_results.append({
            "Review": review[:150] + ("..." if len(review) > 150 else ""), 
            "Predicted Rating": predicted,
            "Actual Rating": actual,
            "Match": predicted == actual,
            "Valid JSON": "True" if isinstance(pred, dict) else "False",
            "Raw Model Output": raw_output
        })

accuracy = round(correct / total, 3) if total > 0 else 0
json_validity = round(valid_json / total, 3) if total > 0 else 0
results_df = pd.DataFrame(detailed_results)
print("\n Results:")
print(results_df)
print(f"\n Accuracy: {accuracy}")
print(f"\n JSON Validity: {json_validity}")
# Out:
#  Running prompt: Classify this Yelp review into 1-5 stars. Provide ...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:56<00:00,  1.12s/it]
#  Results:
#                                                Review  Predicted Rating  \
# 0   We got here around midnight last Friday... the...               NaN
# 1   Brought a friend from Louisiana here.  She say...               5.0
# 2   Every friday, my dad and I eat here. We order ...               4.0
# 3   My husband and I were really, really disappoin...               NaN
# 4   Love this place!  Was in phoenix 3 weeks for w...               3.0
# 5   This hotel is in a good location for getting t...               NaN
# 6   I love that this place has top seafood plates ...               NaN
# 7   Awesome if you like ramen...even awesomer if y...               5.0
# 8   Great place for a "home office" morning. One o...               5.0
# 9   1 star for service, but the food is not ok :( ...               1.0
# 10  Good food and able to manage a large group eas...               5.0
# 11  This place is great!\nIf you talk to anybody t...               NaN
# 12                       Air Jordan! need I say more?               5.0
# 13  There are many other reviews which extol the v...               NaN
# 14  TJ was there for me when my water heater broke...               5.0
# 15  So I was pretty excited about this burger join...               NaN
# 16  I really don't consider myself a Neiman's type...               NaN
# 17  I have been trying to reduce my caloric intake...               5.0
# 18  Great pizza and awesome must have guacamole pi...               5.0
# 19  This is a quaint little airport which is very ...               NaN
# 20  Headed back to Lobby's. How I missed this tast...               2.0
# 21  Simple but really great cajun food prepared in...               NaN
# 22  Staff was very rude, bowling prices weren't di...               NaN
# 23  The staff is really helpful.  I arrived withou...               NaN
# 24  Someone asked the question in the Yelp talk th...               NaN
# 25  After browsing at the Bookman's next door, we ...               NaN
# 26                     Prices are often way too high!               1.0
# 27  I have been to this place twice so far.  The f...               NaN
# 28  The wood saw is always out of service...\nThe ...               2.0
# 29  I've never been to a restaurant where we (a pa...               NaN
# 30  My wife and I live around the corner, hadn't e...               NaN
# 31  Ok, so I have to share my morning experience. ...               1.0
# 32  Found this place by accident.  Not the greates...               4.0
# 33  I'm a little bit country. I'm a little bit roc...               NaN
# 34  This subway is one of the cleanest, and most e...               NaN
# 35  I agree with the other reviewers.. Ink bomb is...               3.0
# 36  Simply the best sandwiches I have ever tasted....               5.0
# 37  Went here today Sunday about 8:50 and it was c...               1.0
# 38  Great BBQ, although not a huge fan of the cafe...               NaN
# 39         Well I just wasted 38 bucks....never again               1.0
# 40  While staying at The Pointe Hilton Tapatio, we...               NaN
# 41  I've eaten here many times, but none as bad as...               1.0
# 42  Some of my friends brought me here last night ...               NaN
# 43  Uh-oh. Where am I? \n\nThe view from atop the ...               4.0
# 44  Mmmmm, Mmmmmm, Great food.  The popcorn shrimp...               NaN
# 45  Decor  functional \nStaff friendly and are rea...               NaN
# 46  I was looking for a comforter for my new bed w...               NaN
# 47  I had lunch today at CASK 63 with a banker to ...               NaN
# 48  While I'm a sushi fan, my husband is a sushi F...               NaN
# 49  If you have to be some place on time, don't us...               4.0
#
#     Actual Rating  Match Valid JSON  \
# 0               4  False      False
# 1               5   True      False
# 2               3  False      False
# 3               1  False      False
# 4               5  False      False
# 5               4  False      False
# 6               4  False      False
# 7               4  False      False
# 8               5   True      False
# 9               1   True      False
# 10              4  False      False
# 11              5  False      False
# 12              3  False      False
# 13              4  False      False
# 14              5   True      False
# 15              2  False      False
# 16              4  False      False
# 17              4  False      False
# 18              5   True      False
# 19              5  False      False
# 20              5  False      False
# 21              5  False      False
# 22              1  False      False
# 23              4  False      False
# 24              4  False      False
# 25              4  False      False
# 26              1   True      False
# 27              4  False      False
# 28              2   True      False
# 29              2  False      False
# 30              1  False      False
# 31              1   True      False
# 32              3  False      False
# 33              4  False      False
# 34              5  False      False
# 35              5  False      False
# 36              5   True      False
# 37              5  False      False
# 38              4  False      False
# 39              2  False      False
# 40              3  False      False
# 41              1   True      False
# 42              1  False      False
# 43              3  False      False
# 44              4  False      False
# 45              4  False      False
# 46              4  False      False
# 47              5  False      False
# 48              4  False      False
# 49              1  False      False
#
#                                      Raw Model Output
# 0   ```\n{\n  "review_text": "We got here around m...
# 1   ```json\n{\n  "review_text": "Brought a friend...
# 2   ```json\n{\n  "review_text": "Every friday, my...
# 3   ```json\n{\n  "review_text": "My husband and I...
# 4   ```json\n{\n  "review_text": "Love this place!...
# 5   ```json\n{\n  "review_text": "This hotel is in...
# 6   ```json\n{\n  "review_text": "I love that this...
# 7   ```json\n{\n  "review_text": "Awesome if you l...
# 8   ```json\n{\n  "review_text": "Great place for ...
# 9   ```json\n{\n  "review_text": "1 star for servi...
# 10  ```json\n{\n  "review_text": "Good food and ab...
# 11  ```json\n{\n  "review_text": "This place is gr...
# 12  ```json\n{\n  "review_text": "Air Jordan! need...
# 13  ```json\n{\n  "review_text": "There are many o...
# 14  ```json\n{\n  "review_text": "TJ was there for...
# 15  ```\n{\n  "review_text": "So I was pretty exci...
# 16  ```json\n{\n  "review_text": "I really don't c...
# 17  ```json\n{\n  "review_text": "I have been tryi...
# 18  ```json\n{\n  "review_text": "Great pizza and ...
# 19  ```json\n{\n  "review_text": "This is a quaint...
# 20  ```json\n{\n  "review_text": "Headed back to L...
# 21  ```json\n{\n  "review_text": "Simple but reall...
# 22  ```json\n{\n  "review_text": "Staff was very r...
# 23  ```json\n{\n  "review_text": "The staff is rea...
# 24  ```json\n{\n  "review_text": "Someone asked th...
# 25  ```json\n{\n  "review_text": "After browsing a...
# 26  ```json\n{\n  "review_text": "Prices are often...
# 27  ```json\n{\n  "review_text": "I have been to t...
# 28  ```\n{\n  "review_text": "The wood saw is alwa...
# 29  ```json\n{\n  "review_text": "I've never been ...
# 30  ```json\n{\n  "review_text": "My wife and I li...
# 31  ```json\n{\n  "review_text": "Ok, so I have to...
# 32  ```json\n{\n  "review_text": "Found this place...
# 33  ```json\n{\n  "review_text": "I'm a little bit...
# 34  ```json\n{\n  "review_text": "This subway is o...
# 35  ```json\n{\n  "review_text": "I agree with the...
# 36  ```json\n{\n  "review_text": "Simply the best ...
# 37  ```json\n{\n  "review_text": "Went here today ...
# 38  ```json\n{\n  "review_text": "Great BBQ, altho...
# 39  ```json\n{\n  "review_text": "Well I just wast...
# 40  ```json\n{\n  "review_text": "While staying at...
# 41  ```json\n{\n  "review_text": "I've eaten here ...
# 42  ```json\n{\n  "review_text": "Some of my frien...
# 43  ```json\n{\n  "review_text": "Uh-oh. Where am ...
# 44  ```json\n{\n  "review_text": "Mmmmm, Mmmmmm, G...
# 45  ```json\n{\n  "review_text": "Decor  functiona...
# 46  ```json\n{\n  "review_text": "I was looking fo...
# 47  ```json\n{\n  "review_text": "I had lunch toda...
# 48  ```json\n{\n  "review_text": "While I'm a sush...
# 49  ```json\n{\n  "review_text": "If you have to b...
#
#  Accuracy: 0.2
#
#  JSON Validity: 0.0

# %% [markdown]
# ### Prompt 2

# %%
prompts = ["Analyze this text carefully and rate it from 1–5 stars based on the reviewer’s satisfaction (1 = very dissatisfied, 5 = very satisfied). Provide JSON output {{'review_text': '...', 'star_rating': <1–5>}}: '{}'"]

detailed_results = []

for p in prompts:
    correct = 0
    total = 0
    valid_json = 0
    
    print(f"\n Running prompt: {p[:50]}...\n")
    for _, row in tqdm(df.iterrows(), total=len(df)):
        review = row["text"]
        actual = row["stars"]
        
        messages = [
            {"role": "system", "content": "You are an expert at sentiment analysis. Always return a JSON object with 'review_text' and 'star_rating'."},
            {"role": "user", "content": p.format(review)},
        ]
        
        response = client.chat.completions.create(
            model="llama-3.3-70b-versatile",  
            messages=messages,
            temperature=0.3,
            max_tokens=100,
        )
        
        raw_output = response.choices[0].message.content.strip()

        pred = None
        try:
            pred = json.loads(raw_output)
            predicted = pred.get("star_rating", None)
            valid_json += 1
        except json.JSONDecodeError:
            match = re.search(r"\b[1-5]\b", raw_output)
            predicted = int(match.group()) if match else None

        if predicted is not None and predicted == actual:
            correct += 1

        total += 1
        
        detailed_results.append({
            "Review": review[:150] + ("..." if len(review) > 150 else ""), 
            "Predicted Rating": predicted,
            "Actual Rating": actual,
            "Match": predicted == actual,
            "Valid JSON": "True" if isinstance(pred, dict) else "False",
            "Raw Model Output": raw_output
        })

accuracy = round(correct / total, 3) if total > 0 else 0
json_validity = round(valid_json / total, 3) if total > 0 else 0
results_df = pd.DataFrame(detailed_results)
print("\n Results:")
print(results_df)
print(f"\n Accuracy: {accuracy}")
print(f"\n JSON Validity: {json_validity}")
# Out:
#  Running prompt: Analyze this text carefully and rate it from 1–5 s...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:55<00:00,  2.32s/it]
#  Results:
#                                                Review  Predicted Rating  \
# 0   We got here around midnight last Friday... the...               NaN
# 1   Brought a friend from Louisiana here.  She say...               5.0
# 2   Every friday, my dad and I eat here. We order ...               4.0
# 3   My husband and I were really, really disappoin...               NaN
# 4   Love this place!  Was in phoenix 3 weeks for w...               3.0
# 5   This hotel is in a good location for getting t...               NaN
# 6   I love that this place has top seafood plates ...               NaN
# 7   Awesome if you like ramen...even awesomer if y...               5.0
# 8   Great place for a "home office" morning. One o...               5.0
# 9   1 star for service, but the food is not ok :( ...               1.0
# 10  Good food and able to manage a large group eas...               5.0
# 11  This place is great!\nIf you talk to anybody t...               NaN
# 12                       Air Jordan! need I say more?               5.0
# 13  There are many other reviews which extol the v...               NaN
# 14  TJ was there for me when my water heater broke...               5.0
# 15  So I was pretty excited about this burger join...               NaN
# 16  I really don't consider myself a Neiman's type...               NaN
# 17  I have been trying to reduce my caloric intake...               5.0
# 18  Great pizza and awesome must have guacamole pi...               5.0
# 19  This is a quaint little airport which is very ...               NaN
# 20  Headed back to Lobby's. How I missed this tast...               2.0
# 21  Simple but really great cajun food prepared in...               NaN
# 22  Staff was very rude, bowling prices weren't di...               NaN
# 23  The staff is really helpful.  I arrived withou...               NaN
# 24  Someone asked the question in the Yelp talk th...               NaN
# 25  After browsing at the Bookman's next door, we ...               NaN
# 26                     Prices are often way too high!               1.0
# 27  I have been to this place twice so far.  The f...               NaN
# 28  The wood saw is always out of service...\nThe ...               2.0
# 29  I've never been to a restaurant where we (a pa...               NaN
# 30  My wife and I live around the corner, hadn't e...               NaN
# 31  Ok, so I have to share my morning experience. ...               1.0
# 32  Found this place by accident.  Not the greates...               4.0
# 33  I'm a little bit country. I'm a little bit roc...               NaN
# 34  This subway is one of the cleanest, and most e...               NaN
# 35  I agree with the other reviewers.. Ink bomb is...               3.0
# 36  Simply the best sandwiches I have ever tasted....               5.0
# 37  Went here today Sunday about 8:50 and it was c...               1.0
# 38  Great BBQ, although not a huge fan of the cafe...               NaN
# 39         Well I just wasted 38 bucks....never again               1.0
# 40  While staying at The Pointe Hilton Tapatio, we...               NaN
# 41  I've eaten here many times, but none as bad as...               1.0
# 42  Some of my friends brought me here last night ...               NaN
# 43  Uh-oh. Where am I? \n\nThe view from atop the ...               3.0
# 44  Mmmmm, Mmmmmm, Great food.  The popcorn shrimp...               NaN
# 45  Decor  functional \nStaff friendly and are rea...               5.0
# 46  I was looking for a comforter for my new bed w...               NaN
# 47  I had lunch today at CASK 63 with a banker to ...               NaN
# 48  While I'm a sushi fan, my husband is a sushi F...               5.0
# 49  If you have to be some place on time, don't us...               4.0
#
#     Actual Rating  Match Valid JSON  \
# 0               4  False      False
# 1               5   True      False
# 2               3  False      False
# 3               1  False      False
# 4               5  False      False
# 5               4  False      False
# 6               4  False      False
# 7               4  False      False
# 8               5   True      False
# 9               1   True      False
# 10              4  False      False
# 11              5  False      False
# 12              3  False      False
# 13              4  False      False
# 14              5   True      False
# 15              2  False      False
# 16              4  False      False
# 17              4  False      False
# 18              5   True      False
# 19              5  False      False
# 20              5  False      False
# 21              5  False      False
# 22              1  False      False
# 23              4  False      False
# 24              4  False      False
# 25              4  False      False
# 26              1   True      False
# 27              4  False      False
# 28              2   True      False
# 29              2  False      False
# 30              1  False      False
# 31              1   True      False
# 32              3  False      False
# 33              4  False      False
# 34              5  False      False
# 35              5  False      False
# 36              5   True      False
# 37              5  False      False
# 38              4  False      False
# 39              2  False      False
# 40              3  False      False
# 41              1   True      False
# 42              1  False      False
# 43              3   True       True
# 44              4  False      False
# 45              4  False      False
# 46              4  False      False
# 47              5  False      False
# 48              4  False      False
# 49              1  False      False
#
#                                      Raw Model Output
# 0   {'review_text': 'We got here around midnight l...
# 1   {'review_text': 'Brought a friend from Louisia...
# 2   {'review_text': 'Every friday, my dad and I ea...
# 3   {'review_text': 'My husband and I were really,...
# 4   {'review_text': 'Love this place!  Was in phoe...
# 5   {'review_text': 'This hotel is in a good locat...
# 6   {'review_text': 'I love that this place has to...
# 7   {'review_text': 'Awesome if you like ramen...e...
# 8   {'review_text': 'Great place for a "home offic...
# 9   {'review_text': '1 star for service, but the f...
# 10  {'review_text': 'Good food and able to manage ...
# 11  {'review_text': 'This place is great! If you t...
# 12  {'review_text': 'Air Jordan! need I say more?'...
# 13  {'review_text': 'There are many other reviews ...
# 14  {'review_text': 'TJ was there for me when my w...
# 15  {'review_text': 'So I was pretty excited about...
# 16  {'review_text': 'I really don\'t consider myse...
# 17  {'review_text': 'I have been trying to reduce ...
# 18  {'review_text': 'Great pizza and awesome must ...
# 19  {'review_text': 'This is a quaint little airpo...
# 20  {'review_text': 'Headed back to Lobby\'s. How ...
# 21  {'review_text': 'Simple but really great cajun...
# 22  {'review_text': 'Staff was very rude, bowling ...
# 23  {'review_text': 'The staff is really helpful. ...
# 24  {'review_text': 'Someone asked the question in...
# 25  {'review_text': 'After browsing at the Bookman...
# 26  {'review_text': 'Prices are often way too high...
# 27  {'review_text': 'I have been to this place twi...
# 28  {'review_text': 'The wood saw is always out of...
# 29  {'review_text': 'I\'ve never been to a restaur...
# 30  {'review_text': 'My wife and I live around the...
# 31  {'review_text': 'The reviewer had a frustratin...
# 32  {'review_text': 'Found this place by accident....
# 33  {'review_text': 'I\'m a little bit country. I\...
# 34  {'review_text': 'This subway is one of the cle...
# 35  {'review_text': 'I agree with the other review...
# 36  {'review_text': 'Simply the best sandwiches I ...
# 37  {'review_text': 'Went here today Sunday about ...
# 38  {'review_text': 'Great BBQ, although not a hug...
# 39  {'review_text': 'Well I just wasted 38 bucks.....
# 40  {'review_text': 'While staying at The Pointe H...
# 41  {'review_text': 'I\'ve eaten here many times, ...
# 42  {'review_text': 'Some of my friends brought me...
# 43  {"review_text": "The reviewer had a mixed expe...
# 44  {'review_text': 'Mmmmm, Mmmmmm, Great food.  T...
# 45  {'review_text': 'Decor is functional, staff is...
# 46  {'review_text': 'I was looking for a comforter...
# 47  {'review_text': 'I had lunch today at CASK 63 ...
# 48  {'review_text': 'The reviewer and their husban...
# 49  {'review_text': 'If you have to be some place ...
#
#  Accuracy: 0.22
#
#  JSON Validity: 0.02

# %% [markdown]
# ### Prompt 3

# %%
prompts = ["Consider both positive and negative aspects of this Yelp review, and decide the most accurate 1–5 star rating that reflects overall satisfaction. Strictly provide only a JSON output with 'review_text' and 'star_rating' : '{}'"]

detailed_results = []

for p in prompts:
    correct = 0
    total = 0
    valid_json = 0
    
    print(f"\n Running prompt: {p[:50]}...\n")
    for _, row in tqdm(df.iterrows(), total=len(df)):
        review = row["text"]
        actual = row["stars"]
        
        messages = [
            {"role": "system", "content": "You are an expert at sentiment analysis. Always return a JSON object with 'review_text' and 'star_rating'."},
            {"role": "user", "content": p.format(review)},
        ]
        
        response = client.chat.completions.create(
            model="llama-3.3-70b-versatile",  
            messages=messages,
            temperature=0.3,
            max_tokens=100,
        )
        
        raw_output = response.choices[0].message.content.strip()

        pred = None
        try:
            pred = json.loads(raw_output)
            predicted = pred.get("star_rating", None)
            valid_json += 1
        except json.JSONDecodeError:
            match = re.search(r"\b[1-5]\b", raw_output)
            predicted = int(match.group()) if match else None

        if predicted is not None and predicted == actual:
            correct += 1

        total += 1
        
        detailed_results.append({
            "Review": review[:150] + ("..." if len(review) > 150 else ""), 
            "Predicted Rating": predicted,
            "Actual Rating": actual,
            "Match": predicted == actual,
            "Valid JSON": "True" if isinstance(pred, dict) else "False",
            "Raw Model Output": raw_output
        })

accuracy = round(correct / total, 3) if total > 0 else 0
json_validity = round(valid_json / total, 3) if total > 0 else 0
results_df = pd.DataFrame(detailed_results)
print("\n Results:")
print(results_df)
print(f"\n Accuracy: {accuracy}")
print(f"\n JSON Validity: {json_validity}")
# Out:
#  Running prompt: Consider both positive and negative aspects of thi...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [01:55<00:00,  2.30s/it]
#  Results:
#                                                Review  Predicted Rating  \
# 0   We got here around midnight last Friday... the...               NaN
# 1   Brought a friend from Louisiana here.  She say...               5.0
# 2   Every friday, my dad and I eat here. We order ...               4.0
# 3   My husband and I were really, really disappoin...               NaN
# 4   Love this place!  Was in phoenix 3 weeks for w...               5.0
# 5   This hotel is in a good location for getting t...               NaN
# 6   I love that this place has top seafood plates ...               NaN
# 7   Awesome if you like ramen...even awesomer if y...               5.0
# 8   Great place for a "home office" morning. One o...               5.0
# 9   1 star for service, but the food is not ok :( ...               1.0
# 10  Good food and able to manage a large group eas...               5.0
# 11  This place is great!\nIf you talk to anybody t...               NaN
# 12                       Air Jordan! need I say more?               5.0
# 13  There are many other reviews which extol the v...               NaN
# 14  TJ was there for me when my water heater broke...               5.0
# 15  So I was pretty excited about this burger join...               2.0
# 16  I really don't consider myself a Neiman's type...               NaN
# 17  I have been trying to reduce my caloric intake...               4.0
# 18  Great pizza and awesome must have guacamole pi...               5.0
# 19  This is a quaint little airport which is very ...               NaN
# 20  Headed back to Lobby's. How I missed this tast...               2.0
# 21  Simple but really great cajun food prepared in...               NaN
# 22  Staff was very rude, bowling prices weren't di...               NaN
# 23  The staff is really helpful.  I arrived withou...               NaN
# 24  Someone asked the question in the Yelp talk th...               NaN
# 25  After browsing at the Bookman's next door, we ...               NaN
# 26                     Prices are often way too high!               2.0
# 27  I have been to this place twice so far.  The f...               NaN
# 28  The wood saw is always out of service...\nThe ...               2.0
# 29  I've never been to a restaurant where we (a pa...               NaN
# 30  My wife and I live around the corner, hadn't e...               NaN
# 31  Ok, so I have to share my morning experience. ...               1.0
# 32  Found this place by accident.  Not the greates...               4.0
# 33  I'm a little bit country. I'm a little bit roc...               NaN
# 34  This subway is one of the cleanest, and most e...               NaN
# 35  I agree with the other reviewers.. Ink bomb is...               3.0
# 36  Simply the best sandwiches I have ever tasted....               5.0
# 37  Went here today Sunday about 8:50 and it was c...               1.0
# 38  Great BBQ, although not a huge fan of the cafe...               NaN
# 39         Well I just wasted 38 bucks....never again               1.0
# 40  While staying at The Pointe Hilton Tapatio, we...               NaN
# 41  I've eaten here many times, but none as bad as...               1.0
# 42  Some of my friends brought me here last night ...               NaN
# 43  Uh-oh. Where am I? \n\nThe view from atop the ...               3.0
# 44  Mmmmm, Mmmmmm, Great food.  The popcorn shrimp...               NaN
# 45  Decor  functional \nStaff friendly and are rea...               5.0
# 46  I was looking for a comforter for my new bed w...               NaN
# 47  I had lunch today at CASK 63 with a banker to ...               NaN
# 48  While I'm a sushi fan, my husband is a sushi F...               NaN
# 49  If you have to be some place on time, don't us...               4.0
#
#     Actual Rating  Match Valid JSON  \
# 0               4  False      False
# 1               5   True       True
# 2               3  False       True
# 3               1  False      False
# 4               5   True       True
# 5               4  False      False
# 6               4  False      False
# 7               4  False       True
# 8               5   True       True
# 9               1   True       True
# 10              4  False       True
# 11              5  False      False
# 12              3  False       True
# 13              4  False      False
# 14              5   True       True
# 15              2   True      False
# 16              4  False      False
# 17              4   True       True
# 18              5   True       True
# 19              5  False      False
# 20              5  False      False
# 21              5  False      False
# 22              1  False      False
# 23              4  False      False
# 24              4  False      False
# 25              4  False      False
# 26              1  False       True
# 27              4  False      False
# 28              2   True       True
# 29              2  False      False
# 30              1  False      False
# 31              1   True       True
# 32              3  False       True
# 33              4  False      False
# 34              5  False      False
# 35              5  False      False
# 36              5   True       True
# 37              5  False      False
# 38              4  False      False
# 39              2  False       True
# 40              3  False      False
# 41              1   True      False
# 42              1  False      False
# 43              3   True      False
# 44              4  False      False
# 45              4  False      False
# 46              4  False      False
# 47              5  False      False
# 48              4  False      False
# 49              1  False      False
#
#                                      Raw Model Output
# 0   {"review_text": "We got here around midnight l...
# 1   {"review_text": "Brought a friend from Louisia...
# 2   {"review_text": "Every friday, my dad and I ea...
# 3   {"review_text": "My husband and I were really,...
# 4   {"review_text": "Love this place!  Was in phoe...
# 5   ```json\n{\n  "review_text": "This hotel is in...
# 6   {"review_text": "I love that this place has to...
# 7   {"review_text": "Awesome if you like ramen...e...
# 8   {"review_text": "Great place for a \"home offi...
# 9   {"review_text": "1 star for service, but the f...
# 10  {"review_text": "Good food and able to manage ...
# 11  {"review_text": "This place is great! If you t...
# 12  {"review_text": "Air Jordan! need I say more?"...
# 13  ```json\n{\n  "review_text": "There are many o...
# 14  {"review_text": "TJ was there for me when my w...
# 15  {"review_text": "So I was pretty excited about...
# 16  {"review_text": "I really don't consider mysel...
# 17  {"review_text": "I have been trying to reduce ...
# 18  {"review_text": "Great pizza and awesome must ...
# 19  {"review_text": "This is a quaint little airpo...
# 20  {"review_text": "Headed back to Lobby's. How I...
# 21  ```json\n{\n  "review_text": "Simple but reall...
# 22  {"review_text": "Staff was very rude, bowling ...
# 23  ```json\n{\n  "review_text": "The staff is rea...
# 24  {"review_text": "Someone asked the question in...
# 25  {"review_text": "After browsing at the Bookman...
# 26  {"review_text": "Prices are often way too high...
# 27  ```json\n{\n  "review_text": "I have been to t...
# 28  {"review_text": "The wood saw is always out of...
# 29  {"review_text": "I've never been to a restaura...
# 30  {"review_text": "My wife and I live around the...
# 31  {"review_text": "Ok, so I have to share my mor...
# 32  {"review_text": "Found this place by accident....
# 33  ```json\n{\n  "review_text": "I'm a little bit...
# 34  {"review_text": "This subway is one of the cle...
# 35  {"review_text": "I agree with the other review...
# 36  {"review_text": "Simply the best sandwiches I ...
# 37  ```json\n{\n  "review_text": "Went here today ...
# 38  ```json\n{\n  "review_text": "Great BBQ, altho...
# 39  {"review_text": "Well I just wasted 38 bucks.....
# 40  {"review_text": "While staying at The Pointe H...
# 41  {"review_text": "I've eaten here many times, b...
# 42  ```json\n{\n  "review_text": "Some of my frien...
# 43  ```json\n{\n  "review_text": "The view from at...
# 44  {"review_text": "Mmmmm, Mmmmmm, Great food.  T...
# 45  ```json\n{\n  "review_text": "Decor is functio...
# 46  {"review_text": "I was looking for a comforter...
# 47  {"review_text": "I had lunch today at CASK 63 ...
# 48  ```json\n{\n  "review_text": "While I'm a sush...
# 49  {"review_text": "If you have to be some place ...
#
#  Accuracy: 0.26
#
#  JSON Validity: 0.34
